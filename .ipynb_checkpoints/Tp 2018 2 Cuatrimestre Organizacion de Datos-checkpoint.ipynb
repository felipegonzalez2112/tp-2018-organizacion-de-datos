# %%
import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt

# %%
#Cargamos el csv

events = pd.read_csv('../events.csv')
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Visualizamos 

events.head()
# Out:
#              timestamp            event    person                        url  \
# 0  2018-05-31 23:38:05  ad campaign hit  0004b0a2  /comprar/iphone/iphone-5s
# 1  2018-05-31 23:38:05     visited site  0004b0a2                        NaN
# 2  2018-05-31 23:38:09   viewed product  0004b0a2                        NaN
# 3  2018-05-31 23:38:40         checkout  0004b0a2                        NaN
# 4  2018-05-29 13:29:25   viewed product  0006a21a                        NaN
#
#      sku              model condition storage           color skus  \
# 0    NaN                NaN       NaN     NaN             NaN  NaN
# 1    NaN                NaN       NaN     NaN             NaN  NaN
# 2   2694          iPhone 5s       Bom    32GB  Cinza espacial  NaN
# 3   2694          iPhone 5s       Bom    32GB  Cinza espacial  NaN
# 4  15338  Samsung Galaxy S8       Bom    64GB         Dourado  NaN
#
#          ...        search_engine channel new_vs_returning        city  \
# 0        ...                  NaN     NaN              NaN         NaN
# 1        ...                  NaN    Paid              New  Camaragibe
# 2        ...                  NaN     NaN              NaN         NaN
# 3        ...                  NaN     NaN              NaN         NaN
# 4        ...                  NaN     NaN              NaN         NaN
#
#        region country device_type screen_resolution operating_system_version  \
# 0         NaN     NaN         NaN               NaN                      NaN
# 1  Pernambuco  Brazil  Smartphone           360x640                Android 6
# 2         NaN     NaN         NaN               NaN                      NaN
# 3         NaN     NaN         NaN               NaN                      NaN
# 4         NaN     NaN         NaN               NaN                      NaN
#
#     browser_version
# 0               NaN
# 1  Chrome Mobile 39
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 23 columns]

# %%
#Observamos que marca y modelo vienen en la misma columna por lo que podemos splitear en 2 columnas con marca y modelo

events['marca'] = events['model'].str.split(' ').str[0]
events['modelo'] = events['model'].str.split(' ').str[1].fillna('') + ' ' + events['model'].str.split(' ').str[2].fillna('')
events.head()
# Out:
#              timestamp            event    person                        url  \
# 0  2018-05-31 23:38:05  ad campaign hit  0004b0a2  /comprar/iphone/iphone-5s
# 1  2018-05-31 23:38:05     visited site  0004b0a2                        NaN
# 2  2018-05-31 23:38:09   viewed product  0004b0a2                        NaN
# 3  2018-05-31 23:38:40         checkout  0004b0a2                        NaN
# 4  2018-05-29 13:29:25   viewed product  0006a21a                        NaN
#
#      sku              model condition storage           color skus    ...      \
# 0    NaN                NaN       NaN     NaN             NaN  NaN    ...
# 1    NaN                NaN       NaN     NaN             NaN  NaN    ...
# 2   2694          iPhone 5s       Bom    32GB  Cinza espacial  NaN    ...
# 3   2694          iPhone 5s       Bom    32GB  Cinza espacial  NaN    ...
# 4  15338  Samsung Galaxy S8       Bom    64GB         Dourado  NaN    ...
#
#   new_vs_returning        city      region country device_type  \
# 0              NaN         NaN         NaN     NaN         NaN
# 1              New  Camaragibe  Pernambuco  Brazil  Smartphone
# 2              NaN         NaN         NaN     NaN         NaN
# 3              NaN         NaN         NaN     NaN         NaN
# 4              NaN         NaN         NaN     NaN         NaN
#
#   screen_resolution operating_system_version   browser_version    marca  \
# 0               NaN                      NaN               NaN      NaN
# 1           360x640                Android 6  Chrome Mobile 39      NaN
# 2               NaN                      NaN               NaN   iPhone
# 3               NaN                      NaN               NaN   iPhone
# 4               NaN                      NaN               NaN  Samsung
#
#       modelo
# 0
# 1
# 2        5s
# 3        5s
# 4  Galaxy S8
#
# [5 rows x 25 columns]

# %%
#Mejorar la visualizacion, marca mas presente en el dataframe

df_marca = events.groupby('marca')['timestamp'].count()
df_marca.plot(kind='bar')

# %%
#Vemos los valores posibles de events

events.event.unique()
# Out:
# array(['ad campaign hit', 'visited site', 'viewed product', 'checkout',
#        'generic listing', 'search engine hit', 'brand listing',
#        'searched products', 'conversion', 'staticpage', 'lead'],
#       dtype=object)

# %%
#Vemos los valores posibles de canales

events.channel.unique()
# Out:
# array([nan, 'Paid', 'Organic', 'Direct', 'Social', 'Referral', 'Email',
#        'Unknown'], dtype=object)

# %%
#Vemos los valores posibles de canales

events.browser_version.unique()
# Out:
# array([nan, 'Chrome Mobile 39', 'Android 5.1', 'Chrome 65.0',
#        'Chrome 66.0', 'Chrome Mobile 66.0', 'Firefox 52', 'Chrome 63.0',
#        'Chrome 64.0', 'Opera 52.0', 'IE 11', 'Chrome Mobile 67.0',
#        'Firefox 60', 'Chrome 67.0', 'Mobile Safari 10',
#        'Samsung Internet 3.3', 'Chrome Mobile 64.0', 'Chrome Mobile 65.0',
#        'Chrome Mobile 63.0', 'Chrome Mobile 33', 'Facebook 176',
#        'Mobile Safari 11', 'Edge 14.14393', 'Android 4.2',
#        'Chrome Mobile 62.0', 'Chrome Mobile 30', 'Edge 16.16299',
#        'Yandex Browser 18.4', 'Chrome 33', 'Chrome 49.0', 'Facebook 168',
#        'Firefox 59', 'UC Browser 12.5', 'Chrome Mobile 57.0',
#        'Chrome 60.0', 'Samsung Internet 6.4', 'Chrome 68.0',
#        'Facebook 171', 'Firefox Mobile 60', 'Facebook 96', 'Facebook 97',
#        'Samsung Internet 5', 'Chrome Mobile 50.0', 'Facebook 174',
#        'Chrome 41.0', 'Mobile Safari 10.3', 'Facebook 172',
#        'Edge 17.17134', 'Mobile Safari 9', 'Chrome Mobile 45.0',
#        'Chrome 61.0', 'Mobile Safari 7', 'Opera 53.0',
#        'Chrome Mobile 55.0', 'Chrome 51.0', 'Android 4.3', 'Chrome 56.0',
#        'Chrome Mobile 53.0', 'Chrome Mobile 43.0', 'Chrome 62.0',
#        'Chrome 59.0', 'Chrome Mobile 34.0', 'IE Mobile 11', 'Firefox 58',
#        'Chromium 66.0', 'Chrome 54.0', 'Edge 15.15063',
#        'Chrome Mobile 54.0', 'UC Browser 7.0', 'Chrome Mobile 28.0',
#        'Facebook 153', 'Chrome Mobile 59.0', 'Chrome Mobile 36.0',
#        'Firefox 57', 'Facebook 175', 'Chrome Mobile iOS 64.0',
#        'Chrome Mobile iOS 65.0', 'Chrome Mobile iOS 66.0', 'Opera 49.0',
#        'Opera 50.0', 'Samsung Internet 6', 'Firefox 40', 'Firefox 48',
#        'Chrome 58.0', 'Facebook 170', 'Other', 'Firefox 38',
#        'Samsung Internet 3.5', 'Android 4.1', 'Chrome Mobile 60.0',
#        'Chrome Mobile 39.0', 'Chrome Mobile 51.0', 'Facebook 95',
#        'Facebook 173', 'Chrome Mobile 30.0', 'Chrome 25.0', 'Firefox 43',
#        'Chrome 56.14', 'Chrome Mobile 56.0', 'Chrome Mobile 61.0',
#        'UC Browser 11.5', 'Samsung Internet 7', 'Facebook 169',
#        'Facebook 62', 'Samsung Internet 4.2', 'Android 4.0',
#        'Facebook 166', 'Chrome Mobile 46.0', 'Facebook 82', 'Firefox 55',
#        'Samsung Internet 7.2', 'Samsung Internet 6.2', 'Facebook 163',
#        'Edge Mobile 14.14393', 'Chrome 40.0', 'Facebook 94',
#        'Chrome Mobile 58.0', 'Facebook 167', 'Facebook 159',
#        'Chrome Mobile 52.0', 'IE Mobile 10', 'Safari 4',
#        'Samsung Internet 5.4', 'Firefox Mobile 59', 'Chrome Mobile 40.0',
#        'Opera 46.0', 'Opera Mobile 35.0', 'Chrome 57.0', 'Chrome 52.0',
#        'Chrome 23.0', 'Chrome Mobile 44.0', 'Chrome 38.0', 'Chrome 46.0',
#        'Chrome Mobile iOS 67.0', 'Mobile Safari UI/WKWebView 10.3',
#        'Firefox 45', 'Chrome 69.0', 'Chrome 28.0', 'Firefox 56',
#        'UC Browser 12.2', 'Firefox 49', 'Chrome Mobile 38.0',
#        'Pale Moon (Firefox Variant) 27.7', 'Firefox 47', 'Facebook 56',
#        'Chrome 47.0', 'Chrome 57.14', 'Safari 11.1', 'Facebook 164',
#        'Chrome Mobile iOS 63.0', 'Firefox 28', 'Firefox 61',
#        'Mobile Safari 4.0', 'Chrome Mobile 35.0', 'Chrome Mobile 47.0',
#        'Facebook 90', 'Facebook 92', 'Opera 42.0', 'Android 4.4',
#        'Firefox 50', 'Chrome 55.0', 'Samsung Internet 4',
#        'Chrome Mobile iOS 61.0', 'Safari 3', 'Firefox 22',
#        'Chromium 60.0', 'Mobile Safari 9.3', 'Facebook 106',
#        'Mobile Safari 11.2', 'Chrome 37.0', 'Chrome 43.0', 'Firefox 51',
#        'Chrome 39', 'Opera Mobile 33.0', 'Chrome Mobile 49.0',
#        'Opera Mini 7.5', 'Chrome 30', 'Safari 11.0', 'Opera Mini 8.0',
#        'Opera Mini 6.5', 'Opera Mini 5.0', 'IE Mobile 9', 'Chrome 32.0',
#        'Edge Mobile 15.15063', 'IE 10', 'Samsung Internet 2.1',
#        'Facebook 117', 'Facebook 158', 'Samsung Internet 2',
#        'Chrome 33.0', 'Amazon Silk 66.3', 'Chrome Mobile 68.0',
#        'Facebook 162', 'Facebook 165', 'Chromium 23.0', 'Android 6',
#        'Opera Mini 35.0', 'Firefox 46', 'Firefox 41',
#        'Yandex Browser 16.9', 'Mobile Safari UI/WKWebView 11.2',
#        'Facebook 145', 'Facebook 98', 'Edge 12.10240', 'Facebook 140',
#        'Facebook 144', 'Opera 51.0', 'Facebook 154', 'Facebook 151',
#        'Chrome 58.6', 'Dragon 49.13', 'Firefox 53', 'Firefox 36',
#        'Chrome Mobile 48.0', 'Chrome 45.0', 'Chrome Mobile 42.0',
#        'Chrome 42.0', 'Safari 8', 'Chrome 58.5', 'Facebook 156',
#        'Firefox 54', 'Safari 10.1', 'Facebook 91', 'Facebook 136',
#        'Mobile Safari 8', 'Puffin 7.5', 'UC Browser 12', 'Facebook 160',
#        'Mobile Safari 10.2', 'Facebook 157', 'Pinterest', 'IE 9',
#        'Facebook 161', 'Mobile Safari 12', 'Chrome 44.0',
#        'Opera Mobile 43.0', 'Opera Mobile 32.0', 'Firefox 30',
#        'Chrome Mobile 26.0', 'Facebook 83', 'Facebook 87', 'Facebook 93',
#        'Puffin 1.6', 'Opera Mini 4.5', 'Chrome 24.0', 'Edge 13.10586',
#        'Chrome 57', 'Firefox 44', 'Chrome 57.16', 'Edge Mobile 13.10586',
#        'Opera Mini 7.1', 'Samsung Internet 1.1', 'Android 2.3',
#        'Chrome Mobile iOS 33.0', 'Chrome Mobile iOS 60.0',
#        'Firefox Mobile 57', 'Facebook 114', 'Opera Mini 21.0',
#        'Opera Mobile 29.0', 'Opera Mini 32.0', 'Chrome Mobile iOS 62.0',
#        'Facebook 88', 'Mobile Safari UI/WKWebView 7.1', 'Facebook 77',
#        'Puffin 7.1', 'Samsung Internet 5.2', 'Yandex Browser 18.6',
#        'Chromium 62.0', 'Chrome 57.18', 'Chrome 53.0', 'Facebook 124',
#        'Maxthon 5.1', 'Mobile Safari 7.1', 'Chrome 48.0', 'Firefox 27',
#        'Chromium 25.0', 'Chrome 50.0', 'Facebook 130', 'Facebook 84',
#        'Firefox 24', 'Chrome 36.0', 'Chrome 58.8', 'Opera 9.80',
#        'Facebook 63', 'Firefox 14.0', 'Firefox 37', 'Firefox 23',
#        'UC Browser 10.10', 'Iron 65.0', 'Android 3.2',
#        'Opera Mobile 46.3', 'Chrome Mobile 33.0', 'Facebook 74',
#        'Facebook 86', 'Facebook 89', 'Facebook 147', 'Chrome 39.0',
#        'Chromium 59.0', 'Chrome Mobile 69.0', 'Chrome 57.20',
#        'Facebook 85', 'Chrome Mobile 31.0', 'Chrome Mobile iOS 57.0',
#        'Chrome Mobile 37', 'Opera Mini 33.0', 'Facebook 125',
#        'Chrome 11.0', 'Vivaldi 1.96', 'Vivaldi 1.94',
#        'Mobile Safari 11.1', 'Chrome 58.3', 'Opera Mini 20.0',
#        'Facebook 152', 'Chromium 37.0', 'Chromium 64.0',
#        'Chrome Mobile 18.0', 'Chrome Mobile iOS 47.0', 'UC Browser 10.7',
#        'Chrome 29.0', 'Chrome 30.0', 'Firefox 33', 'Mobile Safari 6',
#        'Android 3.1', 'Safari 9.1', 'Edge Mobile 15.15254', 'Chrome 35.0',
#        'Chrome 58.1', 'Crosswalk 22.52', 'Safari 10.0', 'Safari 8.0',
#        'Chrome 34.0', 'Mobile Safari 5.1', 'Mobile Safari 11.0',
#        'Vivaldi 1.95', 'Opera 38.0', 'Opera Mini 7.6', 'Firefox 19',
#        'Opera 36.0', 'Chromium 53.0', 'Chromium 58.0', 'Opera Mini 7.0',
#        'Chrome 57.9', 'Firefox 29', 'Android 6.0'], dtype=object)
